# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_csv('oddsportal_data_brut.csv')
df.head(5)
# Out:
#      sports countries               leagues                      pronos  \
# 0  Football  Thailand         Thai League 1  Home/Away, FT including OT
# 1  Football    Brazil               Serie C           O/U 4.5, 1st Half
# 2  Football    Africa  CAF Champions League           O/U 3.5, 1st Half
# 3  Football    Brazil               Serie C           O/U 3.5, 1st Half
# 4  Football  Thailand         Thai League 1           O/U 3.5, 1st Half
#
#        date   time              team_1                team_2 outcome  odds  \
# 0   26 Apr,  02:00  Montreal Canadiens   Washington Capitals       1   6.5
# 1   27 Apr,  14:00     Muang Thong Utd  Nakhon Ratchasima FC    Over  41.0
# 2   27 Apr,  01:30                 CSA               Nautico    Over  34.0
# 3  Tomorr.,  21:00            Pyramids       Orlando Pirates    Over  34.0
# 4   27 Apr,  22:30           Itabaiana          Sao Bernardo    Over  34.0
#
#    value probability
# 0   3.13      46.49%
# 1   2.60       7.65%
# 2   2.45       7.91%
# 3   2.42       7.80%
# 4   2.42       7.78%

# %%
# Nettoyage de la colonne "probability" pour enlever le caractère '%'
df['probability'] =  pd.to_numeric(df['probability'].apply(lambda p: p.replace('%','')))

# Remplacement de "Tomorr.," par la date de demain dans la colonne "date"
today = datetime.now()

# Nettoyage de la colonne "date"
df['date'] = df['date'].apply(lambda date: date.replace(',', '').replace("Tomorr.", (today + timedelta(days=1)).strftime('%d %b')))

# Ajout de l'année actuelle aux dates
current_year = today.year
df['date'] = df['date'] + f" {current_year}"

# Nettoyage de la colonne "date" pour uniformiser le format
df['date'] = pd.to_datetime(df['date'], format='%d %b %Y', errors='coerce')
# Nettoyage de la colonne "time" pour uniformiser le format
df['time'] = pd.to_datetime(df['time'], format='%H:%M', errors='coerce').dt.strftime('%H:%M')

# Vérification des types de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sports       51 non-null     object
#  1   countries    51 non-null     object
#  2   leagues      51 non-null     object
#  3   pronos       51 non-null     object
#  4   date         51 non-null     datetime64[ns]
#  5   time         51 non-null     object
#  6   team_1       51 non-null     object
#  7   team_2       51 non-null     object
#  8   outcome      51 non-null     object
#  9   odds         51 non-null     float64
#  10  value        51 non-null     float64
#  11  probability  51 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 4.9+ KB
